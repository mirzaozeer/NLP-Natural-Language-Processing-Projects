# %% [markdown]
# In this study, we aim for the algorithm to step in and correct the errors in case of any missing letter or word drawing problems or grammatical errors.
#
#
#
# *   **Punctuatıon Correction:**  To correct punctuation marks.
# *   **Grammar Correction:** To correct grammatical mistakes.
# *   **Spell Checker:** To correct word mistakes

# %%
# !pip install happytransformer 
# !pip install textblob
# !pip install sentencepiece
# !pip install transformers
# Out:
# Requirement already satisfied: happytransformer in c:\users\mirza\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: datasets>=1.6.0 in c:\users\mirza\anaconda3\lib\site-packages (from happytransformer) (1.18.3)
# Requirement already satisfied: protobuf in c:\users\mirza\anaconda3\lib\site-packages (from happytransformer) (3.19.4)
# Requirement already satisfied: sentencepiece in c:\users\mirza\anaconda3\lib\site-packages (from happytransformer) (0.1.96)
# Requirement already satisfied: tqdm>=4.43 in c:\users\mirza\anaconda3\lib\site-packages (from happytransformer) (4.62.3)
# Requirement already satisfied: torch>=1.0 in c:\users\mirza\anaconda3\lib\site-packages (from happytransformer) (1.10.2)
# Requirement already satisfied: transformers>=4.4.0 in c:\users\mirza\anaconda3\lib\site-packages (from happytransformer) (4.16.2)
# Requirement already satisfied: xxhash in c:\users\mirza\anaconda3\lib\site-packages (from datasets>=1.6.0->happytransformer) (2.0.2)
# Requirement already satisfied: dill in c:\users\mirza\anaconda3\lib\site-packages (from datasets>=1.6.0->happytransformer) (0.3.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\mirza\anaconda3\lib\site-packages (from datasets>=1.6.0->happytransformer) (1.22.2)
# Requirement already satisfied: packaging in c:\users\mirza\anaconda3\lib\site-packages (from datasets>=1.6.0->happytransformer) (21.3)
# Requirement already satisfied: pandas in c:\users\mirza\anaconda3\lib\site-packages (from datasets>=1.6.0->happytransformer) (1.4.1)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in c:\users\mirza\anaconda3\lib\site-packages (from datasets>=1.6.0->happytransformer) (2022.1.0)
# Requirement already satisfied: aiohttp in c:\users\mirza\anaconda3\lib\site-packages (from datasets>=1.6.0->happytransformer) (3.8.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in c:\users\mirza\anaconda3\lib\site-packages (from datasets>=1.6.0->happytransformer) (0.4.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\mirza\anaconda3\lib\site-packages (from datasets>=1.6.0->happytransformer) (2.27.1)
# Requirement already satisfied: multiprocess in c:\users\mirza\anaconda3\lib\site-packages (from datasets>=1.6.0->happytransformer) (0.70.12.2)
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in c:\users\mirza\anaconda3\lib\site-packages (from datasets>=1.6.0->happytransformer) (7.0.0)
# Requirement already satisfied: pyyaml in c:\users\mirza\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets>=1.6.0->happytransformer) (6.0)
# Requirement already satisfied: filelock in c:\users\mirza\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets>=1.6.0->happytransformer) (3.4.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\mirza\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets>=1.6.0->happytransformer) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\mirza\anaconda3\lib\site-packages (from packaging->datasets>=1.6.0->happytransformer) (3.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mirza\anaconda3\lib\site-packages (from requests>=2.19.0->datasets>=1.6.0->happytransformer) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mirza\anaconda3\lib\site-packages (from requests>=2.19.0->datasets>=1.6.0->happytransformer) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mirza\anaconda3\lib\site-packages (from requests>=2.19.0->datasets>=1.6.0->happytransformer) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\mirza\anaconda3\lib\site-packages (from requests>=2.19.0->datasets>=1.6.0->happytransformer) (2.0.4)
# Requirement already satisfied: colorama in c:\users\mirza\anaconda3\lib\site-packages (from tqdm>=4.43->happytransformer) (0.4.4)
# Requirement already satisfied: sacremoses in c:\users\mirza\anaconda3\lib\site-packages (from transformers>=4.4.0->happytransformer) (0.0.47)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.10.1 in c:\users\mirza\anaconda3\lib\site-packages (from transformers>=4.4.0->happytransformer) (0.11.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\mirza\anaconda3\lib\site-packages (from transformers>=4.4.0->happytransformer) (2022.1.18)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mirza\anaconda3\lib\site-packages (from aiohttp->datasets>=1.6.0->happytransformer) (21.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mirza\anaconda3\lib\site-packages (from aiohttp->datasets>=1.6.0->happytransformer) (1.7.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mirza\anaconda3\lib\site-packages (from aiohttp->datasets>=1.6.0->happytransformer) (1.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mirza\anaconda3\lib\site-packages (from aiohttp->datasets>=1.6.0->happytransformer) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mirza\anaconda3\lib\site-packages (from aiohttp->datasets>=1.6.0->happytransformer) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\mirza\anaconda3\lib\site-packages (from aiohttp->datasets>=1.6.0->happytransformer) (4.0.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\mirza\anaconda3\lib\site-packages (from pandas->datasets>=1.6.0->happytransformer) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mirza\anaconda3\lib\site-packages (from pandas->datasets>=1.6.0->happytransformer) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\mirza\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->datasets>=1.6.0->happytransformer) (1.16.0)
# Requirement already satisfied: joblib in c:\users\mirza\anaconda3\lib\site-packages (from sacremoses->transformers>=4.4.0->happytransformer) (1.1.0)
# Requirement already satisfied: click in c:\users\mirza\anaconda3\lib\site-packages (from sacremoses->transformers>=4.4.0->happytransformer) (8.0.3)
# Requirement already satisfied: textblob in c:\users\mirza\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\users\mirza\anaconda3\lib\site-packages (from textblob) (3.7)
# Requirement already satisfied: joblib in c:\users\mirza\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\mirza\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2022.1.18)
# Requirement already satisfied: click in c:\users\mirza\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.3)
# Requirement already satisfied: tqdm in c:\users\mirza\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.62.3)
# Requirement already satisfied: colorama in c:\users\mirza\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.4)
# Requirement already satisfied: sentencepiece in c:\users\mirza\anaconda3\lib\site-packages (0.1.96)
# Requirement already satisfied: transformers in c:\users\mirza\anaconda3\lib\site-packages (4.16.2)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.10.1 in c:\users\mirza\anaconda3\lib\site-packages (from transformers) (0.11.4)
# Requirement already satisfied: filelock in c:\users\mirza\anaconda3\lib\site-packages (from transformers) (3.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\mirza\anaconda3\lib\site-packages (from transformers) (21.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in c:\users\mirza\anaconda3\lib\site-packages (from transformers) (0.4.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\mirza\anaconda3\lib\site-packages (from transformers) (1.22.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\mirza\anaconda3\lib\site-packages (from transformers) (2022.1.18)
# Requirement already satisfied: tqdm>=4.27 in c:\users\mirza\anaconda3\lib\site-packages (from transformers) (4.62.3)
# Requirement already satisfied: requests in c:\users\mirza\anaconda3\lib\site-packages (from transformers) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mirza\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: sacremoses in c:\users\mirza\anaconda3\lib\site-packages (from transformers) (0.0.47)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\mirza\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\mirza\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (3.0.4)
# Requirement already satisfied: colorama in c:\users\mirza\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\mirza\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mirza\anaconda3\lib\site-packages (from requests->transformers) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mirza\anaconda3\lib\site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mirza\anaconda3\lib\site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: six in c:\users\mirza\anaconda3\lib\site-packages (from sacremoses->transformers) (1.16.0)
# Requirement already satisfied: click in c:\users\mirza\anaconda3\lib\site-packages (from sacremoses->transformers) (8.0.3)
# Requirement already satisfied: joblib in c:\users\mirza\anaconda3\lib\site-packages (from sacremoses->transformers) (1.1.0)

# %%
from happytransformer import HappyTextToText
from happytransformer import TTSettings
from nltk.tokenize import sent_tokenize, word_tokenize
from textblob import TextBlob
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline
import re
import string
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mirza\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mirza\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# #  **PUNCTUATION CORRECTION**
#
# *   Our goal here is to correct punctuation errors in the text.
#
# ### Process;
#
# 1.   In order to make maximum correction in the intro text, we separate the text **by words** (Tokenize).
# 2.   Create a pipeline, detect and label with the "ner" variable, define our model with the model variable, and define tokenize variable and set up our model.
# 3. Finally,  arrange the tokenized text with the determined punctuation marks and obtain the final version of our text.

# %%
tokenizer = AutoTokenizer.from_pretrained("oliverguhr/fullstop-punctuation-multilang-large") #Tokenize model

# %%
model = AutoModelForTokenClassification.from_pretrained("oliverguhr/fullstop-punctuation-multilang-large") #Model

# %% [markdown]
# - Both models you see above are from the Hugging Face (Open source AI community) page
# - For information about the model. [https://huggingface.co/oliverguhr/fullstop-punctuation-multilang-large]

# %%
# 1 and 2

raw_text = "He are moving here I am doing fine How is you? How is go your day? Matt like fish the collection of letters was original used by the ancient Romans"

punctation_model = pipeline('ner', model=model, tokenizer=tokenizer) # Create  model with Pipeline.
processed_text = punctation_model(raw_text) # Apply the model and pass it to the new variable.
processed_text
# Out:
# [{'entity': '0',
#   'score': 0.99992776,
#   'index': 1,
#   'word': '▁He',
#   'start': 0,
#   'end': 2},
#  {'entity': '0',
#   'score': 0.9998388,
#   'index': 2,
#   'word': '▁are',
#   'start': 2,
#   'end': 6},
#  {'entity': '0',
#   'score': 0.9687802,
#   'index': 3,
#   'word': '▁moving',
#   'start': 6,
#   'end': 13},
#  {'entity': '.',
#   'score': 0.69415295,
#   'index': 4,
#   'word': '▁here',
#   'start': 13,
#   'end': 18},
#  {'entity': '0',
#   'score': 0.9999883,
#   'index': 5,
#   'word': '▁I',
#   'start': 18,
#   'end': 20},
#  {'entity': '0',
#   'score': 0.9999676,
#   'index': 6,
#   'word': '▁am',
#   'start': 20,
#   'end': 23},
#  {'entity': '0',
#   'score': 0.99926156,
#   'index': 7,
#   'word': '▁doing',
#   'start': 23,
#   'end': 29},
#  {'entity': '.',
#   'score': 0.8090562,
#   'index': 8,
#   'word': '▁fine',
#   'start': 29,
#   'end': 34},
#  {'entity': '0',
#   'score': 0.9999875,
#   'index': 9,
#   'word': '▁How',
#   'start': 34,
#   'end': 38},
#  {'entity': '0',
#   'score': 0.9999906,
#   'index': 10,
#   'word': '▁is',
#   'start': 38,
#   'end': 41},
#  {'entity': '?',
#   'score': 0.5734973,
#   'index': 11,
#   'word': '▁you',
#   'start': 41,
#   'end': 45},
#  {'entity': '?',
#   'score': 0.7108729,
#   'index': 12,
#   'word': '?',
#   'start': 45,
#   'end': 46},
#  {'entity': '0',
#   'score': 0.99999166,
#   'index': 13,
#   'word': '▁How',
#   'start': 46,
#   'end': 50},
#  {'entity': '0',
#   'score': 0.9999896,
#   'index': 14,
#   'word': '▁is',
#   'start': 50,
#   'end': 53},
#  {'entity': '0',
#   'score': 0.9999442,
#   'index': 15,
#   'word': '▁go',
#   'start': 53,
#   'end': 56},
#  {'entity': '0',
#   'score': 0.99999,
#   'index': 16,
#   'word': '▁your',
#   'start': 56,
#   'end': 61},
#  {'entity': '0',
#   'score': 0.4668531,
#   'index': 17,
#   'word': '▁day',
#   'start': 61,
#   'end': 65},
#  {'entity': '?',
#   'score': 0.39511243,
#   'index': 18,
#   'word': '?',
#   'start': 65,
#   'end': 66},
#  {'entity': ',',
#   'score': 0.69688517,
#   'index': 19,
#   'word': '▁Matt',
#   'start': 66,
#   'end': 71},
#  {'entity': '0',
#   'score': 0.9999783,
#   'index': 20,
#   'word': '▁like',
#   'start': 71,
#   'end': 76},
#  {'entity': '.',
#   'score': 0.86019534,
#   'index': 21,
#   'word': '▁fish',
#   'start': 76,
#   'end': 81},
#  {'entity': '0',
#   'score': 0.9999913,
#   'index': 22,
#   'word': '▁the',
#   'start': 81,
#   'end': 85},
#  {'entity': '0',
#   'score': 0.9999919,
#   'index': 23,
#   'word': '▁collection',
#   'start': 85,
#   'end': 96},
#  {'entity': '0',
#   'score': 0.999561,
#   'index': 24,
#   'word': '▁of',
#   'start': 96,
#   'end': 99},
#  {'entity': '0',
#   'score': 0.9983115,
#   'index': 25,
#   'word': '▁letters',
#   'start': 99,
#   'end': 107},
#  {'entity': '0',
#   'score': 0.99989307,
#   'index': 26,
#   'word': '▁was',
#   'start': 107,
#   'end': 111},
#  {'entity': '0',
#   'score': 0.9999198,
#   'index': 27,
#   'word': '▁original',
#   'start': 111,
#   'end': 120},
#  {'entity': '0',
#   'score': 0.99999154,
#   'index': 28,
#   'word': '▁used',
#   'start': 120,
#   'end': 125},
#  {'entity': '0',
#   'score': 0.99998915,
#   'index': 29,
#   'word': '▁by',
#   'start': 125,
#   'end': 128},
#  {'entity': '0',
#   'score': 0.9999175,
#   'index': 30,
#   'word': '▁the',
#   'start': 128,
#   'end': 132},
#  {'entity': '0',
#   'score': 0.99999046,
#   'index': 31,
#   'word': '▁an',
#   'start': 132,
#   'end': 135},
#  {'entity': '0',
#   'score': 0.99999106,
#   'index': 32,
#   'word': 'cient',
#   'start': 135,
#   'end': 140},
#  {'entity': '.',
#   'score': 0.9999714,
#   'index': 33,
#   'word': '▁Roman',
#   'start': 140,
#   'end': 146},
#  {'entity': '.',
#   'score': 0.9999757,
#   'index': 34,
#   'word': 's',
#   'start': 146,
#   'end': 147}]

# %%
#3

ripe_text = '' # Create a variable to assign the operation that takes place in the for loop.

for i in processed_text:
  result = i['word'].replace('▁',' ') + i['entity'].replace('0','') # Place punctuation marks for each word.
  ripe_text += result
  print(result)
# Out:
#  He
#  are
#  moving
#  here.
#  I
#  am
#  doing
#  fine.
#  How
#  is
#  you?
# ??
#  How
#  is
#  go
#  your
#  day
# ??
#  Matt,
#  like
#  fish.
#  the
#  collection
#  of
#  letters
#  was
#  original
#  used
#  by
#  the
#  an
# cient
#  Roman.
# s.

# %%
print(ripe_text)
# Out:
#  He are moving here. I am doing fine. How is you??? How is go your day?? Matt, like fish. the collection of letters was original used by the ancient Roman.s.

# %% [markdown]
# # **PUNCTUATION CORRECTION TEST**

# %%
raw_text = "while you made the first two of the contract payments as agreed you have refused to make the fincel $3 600 payment"

punctation_model = pipeline('ner', model=model, tokenizer=tokenizer) 
processed_text = punctation_model(raw_text) 

ripe_text = '' 

for i in processed_text:
  result = i['word'].replace('▁',' ') + i['entity'].replace('0','') 
  ripe_text += result
print(ripe_text)
# Out:
#  while you made the first two of the contract payments as agreed, you have refused to make the fincel $3 600 payment.

# %% [raw]
# RUN WITH GRADIO
#
# def punctatıon(sentence):
#     punctation_model = pipeline('ner', model=model, tokenizer=tokenizer)
#     processed_text = punctation_model(sentence)
#     ripe_text = ''
#
#     for i in processed_text:
#         result = i['word'].replace('▁',' ') + i['entity'].replace('0','')
#         ripe_text += result
#
#     return ripe_text
#
# app_inputs = gr.inputs.Textbox(lines=2, placeholder = "Please, enter sentence here...")
#
# interface=gr.Interface(fn = punctatıon,
#                       inputs = app_inputs,
#                       outputs = "text",
#                        theme = "dark",
#                       title = "PUNCTUATION CORRECTOR",
#                       article = "This study created by MIRZA OZER.")
#
# interface.launch()

# %% [markdown]
# # **GRAMMAR CORRECTION**
#
# * Our aim here is to correct grammatical mistakes in the text.
#
# ### Process;
#
# 1. In order to make maximum correction in the introductory text, we separate the text by sentences (Tokenize).
# 2. Make predictions for each of the separated sentences with the for loop.
# 3. Combine the predicted sentences to put them back together.

# %%
happy_tt = HappyTextToText("T5", "vennify/t5-base-grammar-correction") #Model
# Out:
# 02/20/2022 15:42:02 - INFO - happytransformer.happy_transformer -   Using model: cpu

# %%
raw_text = "He are moving here. I am doing fine. How is you?. How is go your they?. Matt like fish. the collection of letters was original used by the ancient Romans." #Tahminleme için kullanacağımız metnimiz
print(raw_text)
# Out:
# He are moving here. I am doing fine. How is you?. How is go your they?. Matt like fish. the collection of letters was original used by the ancient Romans.

# %%
#1

text_tokenize = sent_tokenize(raw_text) # Here separate (Tokenize) the sentences in the text.
#What is important to note here is that the model pays attention to punctuation when tokenizing sentences. 
#If punctuation marks are incorrect or absent, efficiency is reduced.

print(text_tokenize)
# Out:
# ['He are moving here.', 'I am doing fine.', 'How is you?.', 'How is go your they?.', 'Matt like fish.', 'the collection of letters was original used by the ancient Romans.']

# %%
#2

args = TTSettings(num_beams=5, min_length=1) #Use it so that we can fine-tune model.

processed_text= [] # Create a variable to assign the operation that takes place in the for loop.

for i in range(0, len(text_tokenize)):
  modeled_text= happy_tt.generate_text(text_tokenize[i], args=args) 
  processed_text.append(modeled_text.text)
  print(modeled_text.text)
# Out:
# He is moving here.
# I am doing fine.
# How are you?
# How is it going?
# Matt likes fish.
# The collection of letters was originally used by the ancient Romans.

# %%
#3

ripe_text= " ".join(map(str, processed_text)) # Reinstating tokenized and processed text.
print(ripe_text)
# Out:
# He is moving here. I am doing fine. How are you? How is it going? Matt likes fish. The collection of letters was originally used by the ancient Romans.

# %%
# !pip install wrapt
# !pip install anyio
# !pip install gradio
import gradio as gr
# Out:
# Requirement already satisfied: wrapt in c:\users\mirza\anaconda3\lib\site-packages (1.13.3)
# Requirement already satisfied: anyio in c:\users\mirza\anaconda3\lib\site-packages (3.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\mirza\anaconda3\lib\site-packages (from anyio) (1.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\mirza\anaconda3\lib\site-packages (from anyio) (3.3)
# Requirement already satisfied: gradio in c:\users\mirza\anaconda3\lib\site-packages (2.7.5.2)
# Requirement already satisfied: ffmpy in c:\users\mirza\anaconda3\lib\site-packages (from gradio) (0.3.0)
# Requirement already satisfied: fastapi in c:\users\mirza\anaconda3\lib\site-packages (from gradio) (0.73.0)
# Requirement already satisfied: numpy in c:\users\mirza\anaconda3\lib\site-packages (from gradio) (1.22.2)
# Requirement already satisfied: pandas in c:\users\mirza\anaconda3\lib\site-packages (from gradio) (1.4.1)
# Requirement already satisfied: paramiko in c:\users\mirza\anaconda3\lib\site-packages (from gradio) (2.9.2)
# Requirement already satisfied: pillow in c:\users\mirza\anaconda3\lib\site-packages (from gradio) (8.4.0)
# Requirement already satisfied: analytics-python in c:\users\mirza\anaconda3\lib\site-packages (from gradio) (1.4.0)
# Requirement already satisfied: requests in c:\users\mirza\anaconda3\lib\site-packages (from gradio) (2.27.1)
# Requirement already satisfied: uvicorn in c:\users\mirza\anaconda3\lib\site-packages (from gradio) (0.17.4)
# Requirement already satisfied: aiohttp in c:\users\mirza\anaconda3\lib\site-packages (from gradio) (3.8.1)
# Requirement already satisfied: pydub in c:\users\mirza\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart in c:\users\mirza\anaconda3\lib\site-packages (from gradio) (0.0.5)
# Requirement already satisfied: markdown2 in c:\users\mirza\anaconda3\lib\site-packages (from gradio) (2.4.2)
# Requirement already satisfied: pycryptodome in c:\users\mirza\anaconda3\lib\site-packages (from gradio) (3.14.1)
# Requirement already satisfied: matplotlib in c:\users\mirza\anaconda3\lib\site-packages (from gradio) (3.5.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mirza\anaconda3\lib\site-packages (from aiohttp->gradio) (21.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mirza\anaconda3\lib\site-packages (from aiohttp->gradio) (1.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\mirza\anaconda3\lib\site-packages (from aiohttp->gradio) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mirza\anaconda3\lib\site-packages (from aiohttp->gradio) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mirza\anaconda3\lib\site-packages (from aiohttp->gradio) (1.7.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mirza\anaconda3\lib\site-packages (from aiohttp->gradio) (1.3.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\mirza\anaconda3\lib\site-packages (from aiohttp->gradio) (4.0.2)
# Requirement already satisfied: idna>=2.0 in c:\users\mirza\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->gradio) (3.3)
# Requirement already satisfied: six>=1.5 in c:\users\mirza\anaconda3\lib\site-packages (from analytics-python->gradio) (1.16.0)
# Requirement already satisfied: backoff==1.10.0 in c:\users\mirza\anaconda3\lib\site-packages (from analytics-python->gradio) (1.10.0)
# Requirement already satisfied: monotonic>=1.5 in c:\users\mirza\anaconda3\lib\site-packages (from analytics-python->gradio) (1.6)
# Requirement already satisfied: python-dateutil>2.1 in c:\users\mirza\anaconda3\lib\site-packages (from analytics-python->gradio) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mirza\anaconda3\lib\site-packages (from requests->gradio) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mirza\anaconda3\lib\site-packages (from requests->gradio) (2021.10.8)
# Requirement already satisfied: starlette==0.17.1 in c:\users\mirza\anaconda3\lib\site-packages (from fastapi->gradio) (0.17.1)
# Requirement already satisfied: pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2 in c:\users\mirza\anaconda3\lib\site-packages (from fastapi->gradio) (1.8.2)
# Requirement already satisfied: anyio<4,>=3.0.0 in c:\users\mirza\anaconda3\lib\site-packages (from starlette==0.17.1->fastapi->gradio) (3.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\mirza\anaconda3\lib\site-packages (from anyio<4,>=3.0.0->starlette==0.17.1->fastapi->gradio) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\mirza\anaconda3\lib\site-packages (from pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2->fastapi->gradio) (4.1.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mirza\anaconda3\lib\site-packages (from matplotlib->gradio) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\mirza\anaconda3\lib\site-packages (from matplotlib->gradio) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\mirza\anaconda3\lib\site-packages (from matplotlib->gradio) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mirza\anaconda3\lib\site-packages (from matplotlib->gradio) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mirza\anaconda3\lib\site-packages (from matplotlib->gradio) (4.29.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mirza\anaconda3\lib\site-packages (from pandas->gradio) (2021.3)
# Requirement already satisfied: pynacl>=1.0.1 in c:\users\mirza\anaconda3\lib\site-packages (from paramiko->gradio) (1.5.0)
# Requirement already satisfied: bcrypt>=3.1.3 in c:\users\mirza\anaconda3\lib\site-packages (from paramiko->gradio) (3.2.0)
# Requirement already satisfied: cryptography>=2.5 in c:\users\mirza\anaconda3\lib\site-packages (from paramiko->gradio) (3.4.8)
# Requirement already satisfied: cffi>=1.1 in c:\users\mirza\anaconda3\lib\site-packages (from bcrypt>=3.1.3->paramiko->gradio) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\mirza\anaconda3\lib\site-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko->gradio) (2.21)
# Requirement already satisfied: click>=7.0 in c:\users\mirza\anaconda3\lib\site-packages (from uvicorn->gradio) (8.0.3)
# Requirement already satisfied: h11>=0.8 in c:\users\mirza\anaconda3\lib\site-packages (from uvicorn->gradio) (0.13.0)
# Requirement already satisfied: asgiref>=3.4.0 in c:\users\mirza\anaconda3\lib\site-packages (from uvicorn->gradio) (3.5.0)
# Requirement already satisfied: colorama in c:\users\mirza\anaconda3\lib\site-packages (from click>=7.0->uvicorn->gradio) (0.4.4)

# %% [markdown]
# # **GRAMMAR CORRECTION TEST**

# %%
raw_text = "I an Mirza, whose passport is number U12345. I would to litter travel your country between dates the 28.08.2022- - 05.09.2022 for sghtSeing and vacton."

text_tokenize = sent_tokenize(raw_text)

args = TTSettings(num_beams=5, min_length=1)

processed_text= []

for i in range(0, len(text_tokenize)):
  modeled_text= happy_tt.generate_text(text_tokenize[i], args=args) 
  processed_text.append(modeled_text.text)

ripe_text= " ".join(map(str, processed_text)) 
print(ripe_text)
# Out:
# I am Mirza, whose passport number is U12345. I would travel your country between the 28.08.2022- - 05.09.2022 for sightseeing and vacation.

# %% [raw]
# RUN WITH GRADIO
#
# def grammar(sentence):
#     text_tokenize = sent_tokenize(sentence)
#     args = TTSettings(num_beams=5, min_length=1)
#     processed_text= []
#
#     for i in range(0, len(text_tokenize)):
#         modeled_text= happy_tt.generate_text(text_tokenize[i], args=args)
#         processed_text.append(modeled_text.text)
#
#     ripe_text= " ".join(map(str, processed_text))
#     return ripe_text
#
# app_inputs = gr.inputs.Textbox(lines=2, placeholder = "Please, enter sentence here...")
#
# interface=gr.Interface(fn = grammar,
#                       inputs = app_inputs,
#                       outputs = "text",
#                        theme = "dark",
#                       title = "GRAMMAR CORRECTOR",
#                       article = "This study created by MIRZA OZER.")
#
# interface.launch()

# %% [markdown]
# # **SPELL CHECKER**
# * Our goal here is to correct punctuation errors in the text.
#
# ### Process;
#
# 1. In order to make maximum correction in the intro text, we separate the text by words and remove the punctuation marks (Tokenize).
# 2. Apply the words of the seperated text to our model.
# 3. Put the words passing through the model back together

# %%
# 1 ve 2

unpunc_model = re.compile("["+ re.escape(string.punctuation) + "]") # Adjust our model to remove punctuation

unpunc_text = unpunc_model.sub("", raw_text) # Removing punctuation marks from the intro text.

tokenize_text = word_tokenize(unpunc_text)# Separated the words of the text  the punctuation removed.

# %%
tokenize_text
# Out:
# ['I',
#  'an',
#  'Mirza',
#  'whose',
#  'passport',
#  'is',
#  'number',
#  'U12345',
#  'I',
#  'would',
#  'to',
#  'litter',
#  'travel',
#  'your',
#  'country',
#  'between',
#  'dates',
#  'the',
#  '28082022',
#  '05092022',
#  'for',
#  'sghtSeing',
#  'and',
#  'vacton']

# %%
# 3

raw_text = "I am doig fine. How is you?. How is go your thy?. Matt like fsh. the colection of leters was original used by the ancient Romans."

processed_text = [] # Create a variable to assign the operation that takes place in the for loop.

for i in range(0, len(tokenize_text)):
  modeled_text= TextBlob(tokenize_text[i]) #Create mdodel
  correct_word= modeled_text.correct() # Implementing model
  processed_text.append(correct_word) #Transfer the predicted words to the variable we specified.


ripe_text= " ".join(map(str, processed_text)) #Combine the words in the variable passed.
print(ripe_text)
# Out:
# I an Erza whose passport is number U12345 I would to litter travel your country between dates the 28082022 05092022 for sghtSeing and action

# %% [markdown]
# # **SPELL CHECKER TEST**

# %%
unpunc_model = re.compile("["+ re.escape(string.punctuation) + "]") 

unpunc_text = unpunc_model.sub("", raw_text) 

tokenize_text = word_tokenize(unpunc_text)

raw_text = "while you made the first two of the contract payments as agreed you have refused to make the fincel $3 600 payment"

processed_text = [] 

for i in range(0, len(tokenize_text)):
  modeled_text= TextBlob(tokenize_text[i]) 
  correct_word= modeled_text.correct() 
  processed_text.append(correct_word) 


ripe_text= " ".join(map(str, processed_text)) 

print(ripe_text)
# Out:
# I am doing fine Now is you Now is go your thy Watt like fish the collection of letters was original used by the ancient Romans

# %% [raw]
# RUN WITH GRADIO
#
# def spell(sentence):
#     unpunc_model = re.compile("["+ re.escape(string.punctuation) + "]")
#     unpunc_text = unpunc_model.sub("", sentence)
#     tokenize_text = word_tokenize(unpunc_text)
#     processed_text= []
#
#     for i in range(0, len(tokenize_text)):
#         modeled_text= TextBlob(tokenize_text[i])
#         correct_word= modeled_text.correct()
#         processed_text.append(correct_word)
#
#     ripe_text= " ".join(map(str, processed_text))
#     return ripe_text
#
# app_inputs = gr.inputs.Textbox(lines=2, placeholder = "Please, enter sentence here...")
#
# interface=gr.Interface(fn = spell,
#                       inputs = app_inputs,
#                       outputs = "text",
#                        theme = "dark",
#                       title = "SPELL CHECKER",
#                       article = "This study created by MIRZA OZER.")
#
# interface.launch()
